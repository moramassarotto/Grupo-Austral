# %% [markdown]
# <H1> **Introducción a Python para Big Data** : 🎊
#
# Este notebook te guiará a través de los conceptos fundamentales de Python y la librería Pandas, esenciales para el análisis de datos.

# %% [markdown]
# <H3> 1. Primeros pasos con Python 🆎
#
# Comenzaremos con los conceptos básicos de Python, como la creación de variables y la impresión de valores.

# %%
# Asignación y tipos de datos
a = 1 + 1
b = "Big Data"

# Imprimir variables en pantalla
print(a)
print(b)
# Out:
# 2
# Big Data

# %% [markdown]
# <H3> 2. Manejo de datos con Pandas ⛵
#
# Pandas es una librería fundamental para trabajar con datos tabulares. Un DataFrame de Pandas es una estructura similar a una hoja de cálculo, con filas y columnas.

# %% [markdown]
# Crear un DataFrame
#
# Podemos crear un DataFrame a partir de listas de Python.

# %%
# Listas de datos
lista_personajes = ['Luke Skywalker', 'C-3PO', 'Darth Vader']
lista_altura = [172, 167, 202]

# Crear el DataFrame
import pandas as pd

d_star_wars = pd.DataFrame({
    'personaje': lista_personajes,
    'altura': lista_altura
})

# Mostrar el DataFrame y sus tipos de datos
print(d_star_wars)
print("---")
print(d_star_wars.dtypes)
# Out:
#         personaje  altura
# 0  Luke Skywalker     172
# 1           C-3PO     167
# 2     Darth Vader     202
# ---
# personaje    object
# altura        int64
# dtype: object

# %% [markdown]
# <H3> 3. Cargar y explorar un archivo ✈
#
# En el mundo real, los datos rara vez se crean manualmente.
# Veamos como cargar un archivo CSV directamente desde una URL.

# %%
#Antes de comenzar tenemos que instalar la librería skimpy que me permite conocer información estadística de los datos

# !pip install skimpy -q
from skimpy import skim

# %%
# Cargar un archivo CSV desde una URL
starwars = 'https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv'
d_star_wars_url = pd.read_csv(starwars)

# Explorar el DataFrame
# Muestra las primeras 5 filas
print("Primeras 5 filas:")
print(d_star_wars_url.head(5))

# Muestra el número de filas y columnas (filas, columnas)
print("\nDimensiones del DataFrame:")
print(d_star_wars_url.shape)

# Muestra un resumen estadístico de las variables

print("\nEstadísticas del DataFrame:")
skim(d_star_wars_url)
# Out:
# Primeras 5 filas:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human
#
# Dimensiones del DataFrame:
# (87, 10)
#
# Estadísticas del DataFrame:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 87     │ │ string      │ 9     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━┳━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column    ┃ NA  ┃ NA %                   ┃ mean    ┃ sd      ┃ p0  ┃ p25   ┃ p50  ┃ p75  ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━╇━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ height    │   6 │      6.896551724137931 │   174.4 │   34.77 │  66 │   167 │  180 │  191 │   264 │  ▁ ▁█▂  │  │
# │ └───────────┴─────┴────────────────────────┴─────────┴─────────┴─────┴───────┴──────┴──────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃           ┃          ┃           ┃          ┃          ┃ chars per ┃ words    ┃ total     ┃  │
# │ ┃ column    ┃ NA ┃ NA %      ┃ shortest ┃ longest   ┃ min      ┃ max      ┃ row       ┃ per row  ┃ words     ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ name      │  0 │         0 │ Rey      │ Jabba     │ Ackbar   │ Zam      │      10.3 │      1.8 │       157 │  │
# │ │           │    │           │          │ Desilijic │          │ Wesell   │           │          │           │  │
# │ │           │    │           │          │ Tiure     │          │          │           │          │           │  │
# │ │ mass      │ 28 │ 32.183908 │ 77       │ 1,358     │ 1,358    │ 90       │      2.27 │     0.68 │        59 │  │
# │ │           │    │  04597701 │          │           │          │          │           │          │           │  │
# │ │ hair_colo │  6 │ 6.8965517 │ none     │ auburn,   │ auburn   │ white    │      4.81 │     0.97 │        84 │  │
# │ │ r         │    │  24137931 │          │ white     │          │          │           │          │           │  │
# │ │ skin_colo │  2 │ 2.2988505 │ red      │ grey,     │ blue     │ yellow   │      5.94 │      1.2 │       104 │  │
# │ │ r         │    │ 747126435 │          │ green,    │          │          │           │          │           │  │
# │ │           │    │           │          │ yellow    │          │          │           │          │           │  │
# │ │ eye_color │  3 │ 3.4482758 │ red      │ green,    │ black    │ yellow   │      5.04 │     0.99 │        86 │  │
# │ │           │    │ 620689653 │          │ yellow    │          │          │           │          │           │  │
# │ │ birth_yea │ 44 │ 50.574712 │ 8BBY     │ 41.9BBY   │ 102BBY   │ 92BBY    │      5.23 │     0.49 │        43 │  │
# │ │ r         │    │  64367816 │          │           │          │          │           │          │           │  │
# │ │ gender    │  3 │ 3.4482758 │ male     │ hermaphro │ female   │ none     │      4.56 │     0.97 │        84 │  │
# │ │           │    │ 620689653 │          │ dite      │          │          │           │          │           │  │
# │ │ homeworld │ 10 │ 11.494252 │ Tund     │ Cato      │ Alderaan │ Zolan    │      7.14 │     0.98 │        85 │  │
# │ │           │    │ 873563218 │          │ Neimoidia │          │          │           │          │           │  │
# │ │ species   │  5 │ 5.7471264 │ Dug      │ Yoda's    │ Aleena   │ Zabrak   │      6.18 │     0.98 │        85 │  │
# │ │           │    │  36781609 │          │ species   │          │          │           │          │           │  │
# │ └───────────┴────┴───────────┴──────────┴───────────┴──────────┴──────────┴───────────┴──────────┴───────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# <H3>4. Filtrar y seleccionar datos ⛳
#
# Para seleccionar datos específicos de tu DataFrame, usa loc. Con loc puedes seleccionar filas y columnas por sus nombres o etiquetas.
#
#
# El formato loc[filas, columnas] te permite seleccionar datos usando las etiquetas de filas y columnas.
#
# [0, :]: El primer valor (0) selecciona la fila con la etiqueta 0. Los dos puntos (:) significan todas las columnas.
#
# [:, 'nombre_columna']: Los dos puntos (:) seleccionan todas las filas. El nombre de la columna selecciona una columna específica.

# %% [markdown]
# 4.1. Seleccionar columnas

# %%
# Seleccionar una sola columna
#d_star_wars['personaje']

# Seleccionar múltiples columnas
d_star_wars[['personaje', 'altura']]
# Out:
#         personaje  altura
# 0  Luke Skywalker     172
# 1           C-3PO     167
# 2     Darth Vader     202

# %% [markdown]
# 4.2. Seleccionar filas
#
# Podemos seleccionar filas basándote en su posición (índice).
#
# Nota: el uso de 0:2 en loc es inclusivo, lo que significa que incluye los índices 0, 1 y 2.

# %%
# Seleccionar la primera fila
d_star_wars.loc[2, :]
# Out:
# personaje    Darth Vader
# altura               202
# Name: 2, dtype: object

# %%
# Seleccionar las 3 primeras filas
d_star_wars.loc[0:2, :]
# Out:
#         personaje  altura
# 0  Luke Skywalker     172
# 1           C-3PO     167
# 2     Darth Vader     202

# %% [markdown]
# 4.3. Filtrar con condiciones
#
# Podemos usar una condición para filtrar filas que cumplan con un criterio específico. Por ejemplo, encontrar todos los personajes cuya altura sea mayor que 200.

# %%
# Crear un filtro (devuelve True/False para cada fila)
print(d_star_wars)
filtro_altura = d_star_wars['altura'] > 200
filtro_altura

# Aplicar el filtro para obtener solo los registros que cumplen la condición
d_star_wars.loc[filtro_altura, :]
# Out:
#         personaje  altura
# 0  Luke Skywalker     172
# 1           C-3PO     167
# 2     Darth Vader     202
#      personaje  altura
# 2  Darth Vader     202

# %% [markdown]
# 4.4. Reemplazar valores
#
# Podemos combinar el filtrado con la asignación para cambiar valores específicos en el DataFrame.

# %%
# Reemplazar la altura de Darth Vader por 185
d_star_wars.loc[d_star_wars['personaje'] == 'Darth Vader', 'altura'] = 185

# Verificar el cambio
print(d_star_wars.loc[d_star_wars['personaje'] == 'Darth Vader', :])
# Out:
#      personaje  altura
# 2  Darth Vader     185

# %% [markdown]
# <H3>5. Manejar valores nulos (NaN) ⛎
#
# 5.1. Los valores faltantes (NaN) son muy comunes. Es crucial saber cómo identificarlos y manejarlos.

# %%
# Identificar nulos por columna
print("Número de nulos en cada columna:")
print(d_star_wars_url.isnull().sum())
# Out:
# Número de nulos en cada columna:
# name           0
# height         6
# mass          28
# hair_color     6
# skin_color     2
# eye_color      3
# birth_year    44
# gender         3
# homeworld     10
# species        5
# dtype: int64

# %%
d_star_wars_url
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# 0     male  Tatooine   Human
# 1      NaN  Tatooine   Droid
# 2      NaN     Naboo   Droid
# 3     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
# Reemplazar valores nulos en columnas categóricas
valores_a_rellenar = {'homeworld': 'nulo_world', 'species': 'nulo_species'}

d_star_wars_url.fillna(value=valores_a_rellenar, inplace=True)
print(d_star_wars_url)
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender   homeworld       species
# 0     male    Tatooine         Human
# 1      NaN    Tatooine         Droid
# 2      NaN       Naboo         Droid
# 3     male    Tatooine         Human
# 4   female    Alderaan         Human
# ..     ...         ...           ...
# 82  female  nulo_world         Human
# 83    male  nulo_world         Human
# 84    none  nulo_world         Droid
# 85  female  nulo_world  nulo_species
# 86  female       Naboo         Human
#
# [87 rows x 10 columns]

# %%
#Vemos cual es el promedio de altura
print(d_star_wars_url['height'].mean())
# Out:
# 174.35802469135803

# %%
# Reemplazar valores nulos en columnas numéricas con el promedio
promedio_altura = d_star_wars_url['height'].mean()


d_star_wars_url['height'] = d_star_wars_url['height'].fillna(promedio_altura)
d_star_wars_url
# Out:
#               name      height mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker  172.000000   77      blond         fair      blue
# 1            C-3PO  167.000000   75        NaN         gold    yellow
# 2            R2-D2   96.000000   32        NaN  white, blue       red
# 3      Darth Vader  202.000000  136       none        white    yellow
# 4      Leia Organa  150.000000   49      brown        light     brown
# ..             ...         ...  ...        ...          ...       ...
# 82             Rey  174.358025  NaN      brown        light     hazel
# 83     Poe Dameron  174.358025  NaN      brown        light     brown
# 84             BB8  174.358025  NaN       none         none     black
# 85  Captain Phasma  174.358025  NaN        NaN          NaN       NaN
# 86   Padmé Amidala  165.000000   45      brown        light     brown
#
#    birth_year  gender   homeworld       species
# 0       19BBY    male    Tatooine         Human
# 1      112BBY     NaN    Tatooine         Droid
# 2       33BBY     NaN       Naboo         Droid
# 3     41.9BBY    male    Tatooine         Human
# 4       19BBY  female    Alderaan         Human
# ..        ...     ...         ...           ...
# 82        NaN  female  nulo_world         Human
# 83        NaN    male  nulo_world         Human
# 84        NaN    none  nulo_world         Droid
# 85        NaN  female  nulo_world  nulo_species
# 86      46BBY  female       Naboo         Human
#
# [87 rows x 10 columns]

# %%
# Verificar que los nulos fueron reemplazados
skim(d_star_wars_url[['height']])
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 87     │ │ float64     │ 1     │                                                          │
# │ │ Number of columns │ 1      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column     ┃ NA   ┃ NA %    ┃ mean     ┃ sd       ┃ p0   ┃ p25      ┃ p50   ┃ p75      ┃ p100   ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ height     │    0 │       0 │    174.4 │    33.54 │   66 │    167.5 │   178 │    190.5 │    264 │  ▁ ▁█▂   │  │
# │ └────────────┴──────┴─────────┴──────────┴──────────┴──────┴──────────┴───────┴──────────┴────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# 5.2. Eliminar registros con valores nulos
# A veces, en lugar de reemplazar los valores nulos, lo mejor es eliminar por completo las filas o columnas que los contienen. El método dropna() de Pandas te permite hacerlo fácilmente.
#
# Por defecto, dropna() elimina cualquier fila que contenga al menos un valor nulo. Es una forma rápida de limpiar el conjunto de datos si las filas con valores faltantes no son importantes para tu análisis.

# %%
# Eliminar las filas con valores nulos y resetear el índice
d_star_wars_url.dropna(inplace=True)
d_star_wars_url.reset_index(drop=True, inplace=True)

# Ahora skimpy funciona sin problemas de indexación
skim(d_star_wars_url)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 31     │ │ string      │ 9     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column      ┃ NA   ┃ NA %    ┃ mean      ┃ sd        ┃ p0   ┃ p25    ┃ p50    ┃ p75   ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ height      │    0 │       0 │     173.9 │     28.53 │   66 │    170 │    180 │   188 │     202 │  ▁   ▆█  │  │
# │ └─────────────┴──────┴─────────┴───────────┴───────────┴──────┴────────┴────────┴───────┴─────────┴──────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃          ┃           ┃           ┃            ┃ chars per ┃ words per  ┃ total     ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest ┃ longest   ┃ min       ┃ max        ┃ row       ┃ row        ┃ words     ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ name      │  0 │    0 │ Yoda     │ Wicket    │ Ackbar    │ Yoda       │      11.1 │        1.8 │        57 │  │
# │ │           │    │      │          │ Systri    │           │            │           │            │           │  │
# │ │           │    │      │          │ Warrick   │           │            │           │            │           │  │
# │ │ mass      │  0 │    0 │ 77       │ 78.2      │ 113       │ 89         │      2.26 │          1 │        31 │  │
# │ │ hair_colo │  0 │    0 │ none     │ auburn,   │ auburn,   │ white      │       5.1 │        1.1 │        33 │  │
# │ │ r         │    │      │          │ white     │ white     │            │           │            │           │  │
# │ │ skin_colo │  0 │    0 │ red      │ brown     │ blue      │ yellow     │      4.81 │          1 │        32 │  │
# │ │ r         │    │      │          │ mottle    │           │            │           │            │           │  │
# │ │ eye_color │  0 │    0 │ red      │ blue-gray │ black     │ yellow     │      4.94 │          1 │        31 │  │
# │ │ birth_yea │  0 │    0 │ 8BBY     │ 41.9BBY   │ 102BBY    │ 92BBY      │      5.23 │          1 │        31 │  │
# │ │ r         │    │      │          │           │           │            │           │            │           │  │
# │ │ gender    │  0 │    0 │ male     │ female    │ female    │ none       │      4.39 │          1 │        31 │  │
# │ │ homeworld │  0 │    0 │ Naboo    │ Concord   │ Alderaan  │ nulo_world │      7.42 │        1.1 │        34 │  │
# │ │           │    │      │          │ Dawn      │           │            │           │            │           │  │
# │ │ species   │  0 │    0 │ Ewok     │ Yoda's    │ Cerean    │ Zabrak     │      6.06 │        1.1 │        34 │  │
# │ │           │    │      │          │ species   │           │            │           │            │           │  │
# │ └───────────┴────┴──────┴──────────┴───────────┴───────────┴────────────┴───────────┴────────────┴───────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# <H3> 6. Crear nuevas columnas 🛋
#
# Puedes crear una nueva columna en un DataFrame y asignarle valores basados en una condición. Es una forma muy poderosa de derivar información a partir de los datos existentes.

# %%
# Asignamos True si la altura es > 180, de lo contrario, False
d_star_wars['is_tall'] = d_star_wars['altura'] > 180

# Muestra el DataFrame con la nueva columna
print(d_star_wars)
# Out:
#         personaje  altura  is_tall
# 0  Luke Skywalker     172    False
# 1           C-3PO     167    False
# 2     Darth Vader     185     True

# %% [markdown]
# <H3> 7. Copiar un DataFrame ©
#
# Cuando realizas cambios en un DataFrame y quieres conservar la versión original, es una buena práctica hacer una copia. Esto te permite manipular la nueva versión sin afectar la original.

# %%
#Hacer una copia del DataFrame
d_star_wars_copy = d_star_wars.copy()

# Ahora puedes trabajar con d_star_wars_copy sin afectar el original
d_star_wars_copy
# Out:
#         personaje  altura  is_tall
# 0  Luke Skywalker     172    False
# 1           C-3PO     167    False
# 2     Darth Vader     185     True

# %% [markdown]
# ************************************************************************************

# %% [markdown]
# <H2> Ejercicios 🔰
#
# Aquí hay una serie de ejercicios para aplicar lo que aprendiste. ¡No te frustres si te toma tiempo! La práctica es la clave.

# %% [markdown]
# <H3> Ejercicio 1. Carga el archivo heart_disease.csv en un DataFrame llamado d_hd. URL: https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv

# %%
##Ejercicio 1

# Cargar un archivo CSV desde una URL
hd_link = 'https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv'
d_hd = pd.read_csv(hd_link)



# Muestra un resumen estadístico de las variables
print("\nEstadísticas del DataFrame:")
skim(d_hd)
# Out:
# Estadísticas del DataFrame:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 303    │ │ int64       │ 11    │                                                          │
# │ │ Number of columns │ 16     │ │ float64     │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━┳━━━━━┳━━━━━━┳━━━━━━━━┓  │
# │ ┃ column               ┃ NA ┃ NA %               ┃ mean   ┃ sd     ┃ p0  ┃ p25   ┃ p50 ┃ p75 ┃ p100 ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━╇━━━━━╇━━━━━━╇━━━━━━━━┩  │
# │ │ age                  │  0 │                  0 │  54.44 │  9.039 │  29 │    48 │  56 │  61 │   77 │ ▁▄▅█▅▁ │  │
# │ │ chest_pain           │  0 │                  0 │  3.158 │ 0.9601 │   1 │     3 │   3 │   4 │    4 │ ▁ ▃ ▅█ │  │
# │ │ resting_blood_pressu │  0 │                  0 │  131.7 │   17.6 │  94 │   120 │ 130 │ 140 │  200 │ ▃▇█▃▁  │  │
# │ │ re                   │    │                    │        │        │     │       │     │     │      │        │  │
# │ │ serum_cholestoral    │  0 │                  0 │  246.7 │  51.78 │ 126 │   211 │ 241 │ 275 │  564 │  ▂█▃   │  │
# │ │ fasting_blood_sugar  │  0 │                  0 │ 0.1485 │ 0.3562 │   0 │     0 │   0 │   0 │    1 │ █    ▁ │  │
# │ │ resting_electro      │  0 │                  0 │ 0.9901 │  0.995 │   0 │     0 │   1 │   2 │    2 │ █    █ │  │
# │ │ max_heart_rate       │  0 │                  0 │  149.6 │  22.88 │  71 │ 133.5 │ 153 │ 166 │  202 │  ▂▄██▁ │  │
# │ │ exer_angina          │  0 │                  0 │ 0.3267 │ 0.4698 │   0 │     0 │   0 │   1 │    1 │ █    ▄ │  │
# │ │ oldpeak              │  0 │                  0 │   1.04 │  1.161 │   0 │     0 │ 0.8 │ 1.6 │  6.2 │  █▃▁▁  │  │
# │ │ slope                │  0 │                  0 │  1.601 │ 0.6162 │   1 │     1 │   2 │   2 │    3 │ █  █ ▁ │  │
# │ │ num_vessels_flour    │  4 │ 1.3201320132013201 │ 0.6722 │ 0.9374 │   0 │     0 │   0 │   1 │    3 │ █ ▃ ▂▁ │  │
# │ │ thal                 │  2 │ 0.6600660066006601 │  4.734 │   1.94 │   3 │     3 │   3 │   7 │    7 │ █   ▁▆ │  │
# │ │ heart_disease_severi │  0 │                  0 │ 0.9373 │  1.229 │   0 │     0 │   0 │   2 │    4 │ █▃ ▂▂▁ │  │
# │ │ ty                   │    │                    │        │        │     │       │     │     │      │        │  │
# │ │ exter_angina         │  0 │                  0 │ 0.3267 │ 0.4698 │   0 │     0 │   0 │   1 │    1 │ █    ▄ │  │
# │ └──────────────────────┴────┴────────────────────┴────────┴────────┴─────┴───────┴─────┴─────┴──────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓  │
# │ ┃              ┃    ┃      ┃          ┃         ┃        ┃      ┃               ┃ words per    ┃             ┃  │
# │ ┃ column       ┃ NA ┃ NA % ┃ shortest ┃ longest ┃ min    ┃ max  ┃ chars per row ┃ row          ┃ total words ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩  │
# │ │ gender       │  0 │    0 │ male     │ female  │ female │ male │          4.64 │            1 │         303 │  │
# │ │ has_heart_di │  0 │    0 │ no       │ yes     │ no     │ yes  │          2.46 │            1 │         303 │  │
# │ │ sease        │    │      │          │         │        │      │               │              │             │  │
# │ └──────────────┴────┴──────┴──────────┴─────────┴────────┴──────┴───────────────┴──────────────┴─────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# <H3> Ejercicio 2. Muestra los primeros 5 y los últimos 5 registros de d_hd.

# %%
##Ejercicio 2
import pandas as pd

# Load the heart_disease.csv file directly into d_hd as per Ejercicio 1 instruction
d_hd = pd.read_csv('https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv')

print("Primeros 5 registros:")
print(d_hd.head())

print("\nÚltimos 5 registros:")
print(d_hd.tail())
# Out:
# Primeros 5 registros:
#    age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0   63    male           1                     145                233
# 1   67    male           4                     160                286
# 2   67    male           4                     120                229
# 3   37    male           3                     130                250
# 4   41  female           2                     130                204
#
#    fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  oldpeak  \
# 0                    1                2             150            0      2.3
# 1                    0                2             108            1      1.5
# 2                    0                2             129            1      2.6
# 3                    0                0             187            0      3.5
# 4                    0                2             172            0      1.4
#
#    slope  num_vessels_flour  thal  heart_disease_severity  exter_angina  \
# 0      3                0.0   6.0                       0             0
# 1      2                3.0   3.0                       2             1
# 2      2                2.0   7.0                       1             1
# 3      3                0.0   3.0                       0             0
# 4      1                0.0   3.0                       0             0
#
#   has_heart_disease
# 0                no
# 1               yes
# 2               yes
# 3                no
# 4                no
#
# Últimos 5 registros:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 298      1.2      2                0.0   7.0                       1
# 299      3.4      2                2.0   7.0                       2
# 300      1.2      2                1.0   7.0                       3
# 301      0.0      2                1.0   3.0                       1
# 302      0.0      1                NaN   3.0                       0
#
#      exter_angina has_heart_disease
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no

# %% [markdown]
# <H3> Ejercicio 3. Selecciona e imprime las columnas age y has_heart_disease.

# %%
##Ejercicio 3
selected_columns = d_hd[['age', 'has_heart_disease']]
display(selected_columns)
# Out:
#      age has_heart_disease
# 0     63                no
# 1     67               yes
# 2     67               yes
# 3     37                no
# 4     41                no
# ..   ...               ...
# 298   45               yes
# 299   68               yes
# 300   57               yes
# 301   57               yes
# 302   38                no
#
# [303 rows x 2 columns]

# %% [markdown]
# <H3> Ejercicio 4. Crea un filtro para encontrar todos los registros donde colesterol (serum_cholestoral) sea mayor que 250.

# %%
##Ejercicio 4
# Crear un filtro para serum_cholestoral > 250
filtro_colesterol = d_hd['serum_cholestoral'] > 250

# Aplicar el filtro y mostrar los registros resultantes
display(d_hd[filtro_colesterol])
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 7     57  female           4                     120                354
# 8     63    male           4                     130                254
# 11    56  female           2                     140                294
# ..   ...     ...         ...                     ...                ...
# 280   57    male           4                     110                335
# 281   47    male           3                     130                253
# 285   58    male           4                     114                318
# 291   55  female           2                     132                342
# 298   45    male           1                     110                264
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 1                      0                2             108            1
# 6                      0                2             160            0
# 7                      0                0             163            1
# 8                      0                2             147            0
# 11                     0                2             153            0
# ..                   ...              ...             ...          ...
# 280                    0                0             143            1
# 281                    0                0             179            0
# 285                    0                1             140            0
# 291                    0                0             166            0
# 298                    0                0             132            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 1        1.5      2                3.0   3.0                       2
# 6        3.6      3                2.0   3.0                       3
# 7        0.6      1                0.0   3.0                       0
# 8        1.4      2                1.0   7.0                       2
# 11       1.3      2                0.0   3.0                       0
# ..       ...    ...                ...   ...                     ...
# 280      3.0      2                1.0   7.0                       2
# 281      0.0      1                0.0   3.0                       0
# 285      4.4      3                3.0   6.0                       4
# 291      1.2      1                0.0   3.0                       0
# 298      1.2      2                0.0   7.0                       1
#
#      exter_angina has_heart_disease
# 1               1               yes
# 6               0               yes
# 7               1                no
# 8               0               yes
# 11              0                no
# ..            ...               ...
# 280             1               yes
# 281             0                no
# 285             0               yes
# 291             0                no
# 298             0               yes
#
# [127 rows x 16 columns]

# %% [markdown]
# <H3> Ejercicio 5. identificar qué variables tienen valores nulos.

# %%
##Ejercicio 5
# Identificar nulos por columna
print("Número de nulos en cada columna:")
print(d_hd.isnull().sum())
# Out:
# Número de nulos en cada columna:
# age                       0
# gender                    0
# chest_pain                0
# resting_blood_pressure    0
# serum_cholestoral         0
# fasting_blood_sugar       0
# resting_electro           0
# max_heart_rate            0
# exer_angina               0
# oldpeak                   0
# slope                     0
# num_vessels_flour         4
# thal                      2
# heart_disease_severity    0
# exter_angina              0
# has_heart_disease         0
# dtype: int64

# %% [markdown]
# <H3> Ejercicio 6. Reemplaza los valores nulos de la columna thal por un valor de 999.

# %%
##Ejercicio 6
d_hd['thal'].fillna(999, inplace=True)
print(d_hd)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 0        2.3      3                0.0   6.0                       0
# 1        1.5      2                3.0   3.0                       2
# 2        2.6      2                2.0   7.0                       1
# 3        3.5      3                0.0   3.0                       0
# 4        1.4      1                0.0   3.0                       0
# ..       ...    ...                ...   ...                     ...
# 298      1.2      2                0.0   7.0                       1
# 299      3.4      2                2.0   7.0                       2
# 300      1.2      2                1.0   7.0                       3
# 301      0.0      2                1.0   3.0                       1
# 302      0.0      1                NaN   3.0                       0
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no
#
# [303 rows x 16 columns]
# /tmp/ipykernel_6578/342482131.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d_hd['thal'].fillna(999, inplace=True)

# %% [markdown]
# <H3> Ejercicio 7. Filtrar por múltiples condiciones:
#
# Utiliza el DataFrame d_hd y filtra para encontrar todos los registros de pacientes que tienen más de 60 años Y un nivel de colesterol (serum_cholestoral) superior a 250.

# %%
##Ejercicio 7
d_hd[(d_hd['age'] > 60) & (d_hd['serum_cholestoral'] > 250)]
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 8     63    male           4                     130                254
# 32    64    male           3                     140                335
# 42    71  female           2                     160                302
# 44    61  female           4                     130                330
# 48    65  female           3                     140                417
# 70    65  female           3                     155                269
# 71    67    male           4                     125                254
# 72    62    male           4                     120                267
# 75    65  female           3                     160                360
# 83    68    male           3                     180                274
# 90    66    male           4                     120                302
# 94    63  female           3                     135                252
# 103   71  female           3                     110                265
# 108   61    male           4                     120                260
# 110   61  female           4                     145                307
# 114   62  female           3                     130                263
# 118   63    male           4                     130                330
# 119   65    male           4                     135                254
# 121   63  female           4                     150                407
# 124   65    male           1                     138                282
# 137   62    male           2                     120                281
# 143   64    male           3                     125                309
# 152   67  female           3                     115                564
# 155   70    male           4                     130                322
# 159   68    male           3                     118                277
# 161   77    male           4                     125                304
# 170   70    male           3                     160                269
# 173   62  female           4                     140                394
# 189   69    male           3                     140                254
# 193   62  female           4                     138                294
# 195   67    male           4                     100                299
# 201   64  female           4                     180                325
# 203   64  female           3                     140                313
# 218   64  female           4                     130                303
# 224   63  female           4                     108                269
# 227   67  female           3                     152                277
# 233   74  female           2                     120                269
# 252   64    male           4                     128                263
# 276   66  female           3                     146                278
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 1                      0                2             108            1
# 6                      0                2             160            0
# 8                      0                2             147            0
# 32                     0                0             158            0
# 42                     0                0             162            0
# 44                     0                2             169            0
# 48                     1                2             157            0
# 70                     0                0             148            0
# 71                     1                0             163            0
# 72                     0                0              99            1
# 75                     0                2             151            0
# 83                     1                2             150            1
# 90                     0                2             151            0
# 94                     0                2             172            0
# 103                    1                2             130            0
# 108                    0                0             140            1
# 110                    0                2             146            1
# 114                    0                0              97            0
# 118                    1                2             132            1
# 119                    0                2             127            0
# 121                    0                2             154            0
# 124                    1                2             174            0
# 137                    0                2             103            0
# 143                    0                0             131            1
# 152                    0                2             160            0
# 155                    0                2             109            0
# 159                    0                0             151            0
# 161                    0                2             162            1
# 170                    0                0             112            1
# 173                    0                2             157            0
# 189                    0                2             146            0
# 193                    1                0             106            0
# 195                    0                2             125            1
# 201                    0                0             154            1
# 203                    0                0             133            0
# 218                    0                0             122            0
# 224                    0                0             169            1
# 227                    0                0             172            0
# 233                    0                2             121            1
# 252                    0                0             105            1
# 276                    0                2             152            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 1        1.5      2                3.0   3.0                       2
# 6        3.6      3                2.0   3.0                       3
# 8        1.4      2                1.0   7.0                       2
# 32       0.0      1                0.0   3.0                       1
# 42       0.4      1                2.0   3.0                       0
# 44       0.0      1                0.0   3.0                       1
# 48       0.8      1                1.0   3.0                       0
# 70       0.8      1                0.0   3.0                       0
# 71       0.2      2                2.0   7.0                       3
# 72       1.8      2                2.0   7.0                       1
# 75       0.8      1                0.0   3.0                       0
# 83       1.6      2                0.0   7.0                       3
# 90       0.4      2                0.0   3.0                       0
# 94       0.0      1                0.0   3.0                       0
# 103      0.0      1                1.0   3.0                       0
# 108      3.6      2                1.0   7.0                       2
# 110      1.0      2                0.0   7.0                       1
# 114      1.2      2                1.0   7.0                       2
# 118      1.8      1                3.0   7.0                       3
# 119      2.8      2                1.0   7.0                       2
# 121      4.0      2                3.0   7.0                       4
# 124      1.4      2                1.0   3.0                       1
# 137      1.4      2                1.0   7.0                       3
# 143      1.8      2                0.0   7.0                       1
# 152      1.6      2                0.0   7.0                       0
# 155      2.4      2                3.0   3.0                       1
# 159      1.0      1                1.0   7.0                       0
# 161      0.0      1                3.0   3.0                       4
# 170      2.9      2                1.0   7.0                       3
# 173      1.2      2                0.0   3.0                       0
# 189      2.0      2                3.0   7.0                       2
# 193      1.9      2                3.0   3.0                       2
# 195      0.9      2                2.0   3.0                       3
# 201      0.0      1                0.0   3.0                       0
# 203      0.2      1                0.0   7.0                       0
# 218      2.0      2                2.0   3.0                       0
# 224      1.8      2                2.0   3.0                       1
# 227      0.0      1                1.0   3.0                       0
# 233      0.2      1                1.0   3.0                       0
# 252      0.2      2                1.0   7.0                       0
# 276      0.0      2                1.0   3.0                       0
#
#      exter_angina has_heart_disease
# 1               1               yes
# 6               0               yes
# 8               0               yes
# 32              0               yes
# 42              0                no
# 44              0               yes
# 48              0                no
# 70              0                no
# 71              0               yes
# 72              1               yes
# 75              0                no
# 83              1               yes
# 90              0                no
# 94              0                no
# 103             0                no
# 108             1               yes
# 110             1               yes
# 114             0               yes
# 118             1               yes
# 119             0               yes
# 121             0               yes
# 124             0               yes
# 137             0               yes
# 143             1               yes
# 152             0                no
# 155             0               yes
# 159             0                no
# 161             1               yes
# 170             1               yes
# 173             0                no
# 189             0               yes
# 193             0               yes
# 195             1               yes
# 201             1                no
# 203             0                no
# 218             0                no
# 224             1               yes
# 227             0                no
# 233             1                no
# 252             1                no
# 276             0                no

# %% [markdown]
# <H3> Ejercicio 8. Reemplazar valores en una columna:
#
# Selecciona la columna slope del DataFrame d_hd. Reemplaza el valor 1 por el string 'ascendente' y el valor 2 por 'descendente'. Muestra el resultado (no necesitas guardarlo en el DataFrame original).

# %%
##Ejercicio 8
d_hd['slope'] = d_hd['slope'].replace({1: 'ascendente', 2: 'descendente'})
display(d_hd)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak        slope  num_vessels_flour  thal  heart_disease_severity  \
# 0        2.3            3                0.0   6.0                       0
# 1        1.5  descendente                3.0   3.0                       2
# 2        2.6  descendente                2.0   7.0                       1
# 3        3.5            3                0.0   3.0                       0
# 4        1.4   ascendente                0.0   3.0                       0
# ..       ...          ...                ...   ...                     ...
# 298      1.2  descendente                0.0   7.0                       1
# 299      3.4  descendente                2.0   7.0                       2
# 300      1.2  descendente                1.0   7.0                       3
# 301      0.0  descendente                1.0   3.0                       1
# 302      0.0   ascendente                NaN   3.0                       0
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no
#
# [303 rows x 16 columns]

# %% [markdown]
# <H3>Ejercicio 9. Crear una nueva columna:
#
# En el DataFrame d_hd, crea una nueva columna llamada is_healthy. Asigna el valor True si el paciente no tiene enfermedad del corazón (es decir, el valor en heart_disease_severity es 0) y False en caso contrario. Muestra el DataFrame con la nueva columna

# %%
##Ejercicio 9
d_hd['is_healthy'] = d_hd['heart_disease_severity'] == 0
display(d_hd)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak        slope  num_vessels_flour  thal  heart_disease_severity  \
# 0        2.3            3                0.0   6.0                       0
# 1        1.5  descendente                3.0   3.0                       2
# 2        2.6  descendente                2.0   7.0                       1
# 3        3.5            3                0.0   3.0                       0
# 4        1.4   ascendente                0.0   3.0                       0
# ..       ...          ...                ...   ...                     ...
# 298      1.2  descendente                0.0   7.0                       1
# 299      3.4  descendente                2.0   7.0                       2
# 300      1.2  descendente                1.0   7.0                       3
# 301      0.0  descendente                1.0   3.0                       1
# 302      0.0   ascendente                NaN   3.0                       0
#
#      exter_angina has_heart_disease  is_healthy
# 0               0                no        True
# 1               1               yes       False
# 2               1               yes       False
# 3               0                no        True
# 4               0                no        True
# ..            ...               ...         ...
# 298             0               yes       False
# 299             0               yes       False
# 300             1               yes       False
# 301             0               yes       False
# 302             0                no        True
#
# [303 rows x 17 columns]

# %% [markdown]
# <H3> Ejercicio 10. Eliminar registros con nulos:
#
# Crea una copia del DataFrame d_hd llamada d_hd_clean. Usa el método dropna() para eliminar todos los registros que contengan al menos un valor nulo. Luego, usa status() para verificar que ya no hay valores nulos en d_hd_clean.

# %%
##Ejercicio 10
# !pip install skimpy -q
from skimpy import skim
d_hd_clean = d_hd.copy()
d_hd_clean.dropna(inplace=True)
skim(d_hd_clean)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 299    │ │ int64       │ 10    │                                                          │
# │ │ Number of columns │ 16     │ │ float64     │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━━┓  │
# │ ┃ column                     ┃ NA  ┃ NA %  ┃ mean    ┃ sd      ┃ p0   ┃ p25  ┃ p50  ┃ p75    ┃ p100 ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━━┩  │
# │ │ age                        │   0 │     0 │   54.53 │   9.021 │   29 │   48 │   56 │     61 │   77 │ ▁▄▅█▅▁ │  │
# │ │ chest_pain                 │   0 │     0 │   3.161 │  0.9629 │    1 │    3 │    3 │      4 │    4 │ ▁ ▃ ▅█ │  │
# │ │ resting_blood_pressure     │   0 │     0 │   131.7 │   17.71 │   94 │  120 │  130 │    140 │  200 │ ▃▇█▃▁  │  │
# │ │ serum_cholestoral          │   0 │     0 │   247.1 │   51.91 │  126 │  211 │  242 │  275.5 │  564 │  ▂█▃   │  │
# │ │ fasting_blood_sugar        │   0 │     0 │  0.1472 │  0.3549 │    0 │    0 │    0 │      0 │    1 │ █    ▁ │  │
# │ │ resting_electro            │   0 │     0 │  0.9967 │  0.9949 │    0 │    0 │    1 │      2 │    2 │ █    █ │  │
# │ │ max_heart_rate             │   0 │     0 │   149.5 │   22.95 │   71 │  133 │  153 │  165.5 │  202 │  ▂▄██▁ │  │
# │ │ exer_angina                │   0 │     0 │  0.3278 │  0.4702 │    0 │    0 │    0 │      1 │    1 │ █    ▄ │  │
# │ │ oldpeak                    │   0 │     0 │   1.052 │   1.164 │    0 │    0 │  0.8 │    1.6 │  6.2 │  █▃▁▁  │  │
# │ │ num_vessels_flour          │   0 │     0 │  0.6722 │  0.9374 │    0 │    0 │    0 │      1 │    3 │ █ ▃ ▂▁ │  │
# │ │ thal                       │   0 │     0 │   11.38 │    81.2 │    3 │    3 │    3 │      7 │  999 │   █    │  │
# │ │ heart_disease_severity     │   0 │     0 │  0.9465 │   1.233 │    0 │    0 │    0 │      2 │    4 │ █▃ ▂▂▁ │  │
# │ │ exter_angina               │   0 │     0 │  0.3278 │  0.4702 │    0 │    0 │    0 │      1 │    1 │ █    ▄ │  │
# │ └────────────────────────────┴─────┴───────┴─────────┴─────────┴──────┴──────┴──────┴────────┴──────┴────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column                            ┃ true            ┃ true rate                     ┃ hist                 ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ is_healthy                        │             161 │                          0.54 │        ▇    █        │  │
# │ └───────────────────────────────────┴─────────────────┴───────────────────────────────┴──────────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓  │
# │ ┃              ┃    ┃      ┃          ┃         ┃        ┃      ┃               ┃ words per    ┃             ┃  │
# │ ┃ column       ┃ NA ┃ NA % ┃ shortest ┃ longest ┃ min    ┃ max  ┃ chars per row ┃ row          ┃ total words ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩  │
# │ │ gender       │  0 │    0 │ male     │ female  │ female │ male │          4.65 │            1 │         299 │  │
# │ │ has_heart_di │  0 │    0 │ no       │ yes     │ no     │ yes  │          2.46 │            1 │         299 │  │
# │ │ sease        │    │      │          │         │        │      │               │              │             │  │
# │ └──────────────┴────┴──────┴──────────┴─────────┴────────┴──────┴───────────────┴──────────────┴─────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ************************************************************************************
